# %%
import sys
sys.path.append('../dftplot/band')
from py4vasp import Calculation
calc = Calculation.from_path('../data/band')

# %%
calc.band.print()
# Out:
# band data:
#     30 k-points
#     160 bands
# projectors:
#     atoms: C, H, Au
#     orbitals: s, py, pz, px, dxy, dyz, dz2, dxz, dx2y2, fy3x2, fxyz, fyz2, fz3, fxz2, fzx2, fx3

# %%
calc.band.to_csv(filename='band.csv')

# %%
calc.band.plot()
